# %% [markdown]
# # BODAQS Library Manager
#
# View session metadata, edit descriptions, manage canonical session notes, and manage canonical aggregations.

# %%
from IPython.display import display
from bodaqs_analysis.ui import make_library_manager

mgr = make_library_manager(artifacts_dir="artifacts")
display(mgr["ui"])
