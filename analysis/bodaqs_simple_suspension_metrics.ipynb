# %% [markdown]
# # BODAQS Simple Suspension Metrics

# %%
from IPython.display import display
from bodaqs_analysis.widgets.session_selector import make_session_selector
from bodaqs_analysis.dashboards import make_simple_suspension_metrics_dashboard

# Dashboard parameters: keep these aligned with the current event schema and one-step workflow.
FRONT_SUSPENSION_SELECTOR = {"end": "front", "domain": "wheel"}
REAR_SUSPENSION_SELECTOR = {"end": "rear", "domain": "wheel"}
FRONT_EVENT_SIGNAL_SELECTOR = {"end": "front", "domain": "wheel"}
REAR_EVENT_SIGNAL_SELECTOR = {"end": "rear", "domain": "wheel"}

SCATTER_COMPRESSION_EVENT_ID = "compressions_all>25"
SCATTER_REBOUND_EVENT_ID = "rebounds_all>25"
SCATTER_X_METRIC = "m_peak_disp_max"
SCATTER_COMPRESSION_Y_METRIC = "m_interval_vel_max"
SCATTER_REBOUND_Y_METRIC = "m_interval_vel_min"

sel = make_session_selector(artifacts_dir="artifacts", select_first_by_default=True)
display(sel["ui"])

dashboard = make_simple_suspension_metrics_dashboard(
    sel,
    front_displacement_selector=FRONT_SUSPENSION_SELECTOR,
    rear_displacement_selector=REAR_SUSPENSION_SELECTOR,
    front_velocity_selector=FRONT_SUSPENSION_SELECTOR,
    rear_velocity_selector=REAR_SUSPENSION_SELECTOR,
    front_event_signal_selector=FRONT_EVENT_SIGNAL_SELECTOR,
    rear_event_signal_selector=REAR_EVENT_SIGNAL_SELECTOR,
    compression_event_type=SCATTER_COMPRESSION_EVENT_ID,
    rebound_event_type=SCATTER_REBOUND_EVENT_ID,
    scatter_x_metric=SCATTER_X_METRIC,
    compression_y_metric=SCATTER_COMPRESSION_Y_METRIC,
    rebound_y_metric=SCATTER_REBOUND_Y_METRIC,
)
display(dashboard["ui"])
# Out:
# VBox(children=(HBox(children=(Checkbox(value=True, description='Autosave selection', indent=False, layout=Layo…
# metric_scatter: Could not resolve any event contexts via schema+registry. Sample (session_key, schema_id, signal_col):
#                                       session_key           schema_id                            signal_col
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_25_50  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_25_50 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_50_75 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_50_75  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45 compressions_75_100 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45 compressions_75_100  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45      rebounds_25_50  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45      rebounds_25_50 front_shock_vel_dom_suspension [mm/s]
# metric_scatter: Could not resolve any event contexts via schema+registry. Sample (session_key, schema_id, signal_col):
#                                       session_key           schema_id                            signal_col
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_25_50  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_25_50 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_50_75 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_50_75  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45 compressions_75_100 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45 compressions_75_100  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45      rebounds_25_50  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45      rebounds_25_50 front_shock_vel_dom_suspension [mm/s]
# metric_scatter: Could not resolve any event contexts via schema+registry. Sample (session_key, schema_id, signal_col):
#                                       session_key           schema_id                            signal_col
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_25_50  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_25_50 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_50_75 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_50_75  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45 compressions_75_100 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45 compressions_75_100  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45      rebounds_25_50  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45      rebounds_25_50 front_shock_vel_dom_suspension [mm/s]
# metric_scatter: Could not resolve any event contexts via schema+registry. Sample (session_key, schema_id, signal_col):
#                                       session_key           schema_id                            signal_col
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_25_50  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_25_50 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_50_75 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_50_75  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45 compressions_75_100 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45 compressions_75_100  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45      rebounds_25_50  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45      rebounds_25_50 front_shock_vel_dom_suspension [mm/s]
# metric_scatter: Could not resolve any event contexts via schema+registry. Sample (session_key, schema_id, signal_col):
#                                       session_key           schema_id                            signal_col
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_25_50  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_25_50 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_50_75 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_50_75  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45 compressions_75_100 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45 compressions_75_100  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45      rebounds_25_50  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45      rebounds_25_50 front_shock_vel_dom_suspension [mm/s]
# metric_scatter: Could not resolve any event contexts via schema+registry. Sample (session_key, schema_id, signal_col):
#                                       session_key           schema_id                            signal_col
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_25_50  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_25_50 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_50_75 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45  compressions_50_75  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45 compressions_75_100 front_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45 compressions_75_100  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45      rebounds_25_50  rear_shock_vel_dom_suspension [mm/s]
# run_2026-02-16T15-55-34_AWST::2026-02-01_09-43-45      rebounds_25_50 front_shock_vel_dom_suspension [mm/s]
# VBox(children=(HBox(children=(Checkbox(value=False, description='Show engineering units (mm)', indent=False),)…

# %%
import sys, importlib.util, site

print("sys.executable =", sys.executable)
print("sys.version    =", sys.version)
print("ipydatagrid    =", importlib.util.find_spec("ipydatagrid"))
print("ipywidgets     =", importlib.util.find_spec("ipywidgets"))
print("site-packages  =", site.getsitepackages())
# Out:
# sys.executable = C:\Users\benco\dev\BODAQS\.venv\Scripts\python.exe
# sys.version    = 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# ipydatagrid    = None
# ipywidgets     = ModuleSpec(name='ipywidgets', loader=<_frozen_importlib_external.SourceFileLoader object at 0x000001F2B133F550>, origin='C:\\Users\\benco\\dev\\BODAQS\\.venv\\Lib\\site-packages\\ipywidgets\\__init__.py', submodule_search_locations=['C:\\Users\\benco\\dev\\BODAQS\\.venv\\Lib\\site-packages\\ipywidgets'])
# site-packages  = ['C:\\Users\\benco\\dev\\BODAQS\\.venv', 'C:\\Users\\benco\\dev\\BODAQS\\.venv\\Lib\\site-packages']
