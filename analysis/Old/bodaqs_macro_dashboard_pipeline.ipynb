# %% [markdown]
# # BODAQS Macro Analysis Dashboard
#
# This notebook drives the extracted backend (`bodaqs_analysis`) with minimal editing.
#
# Workflow:
# 1. Load CSV
# 2. Normalize (zero + scale)
# 3. Estimate velocity/acceleration
# 4. Load event schema + detect events
# 5. Inspect metrics / quick plots

# %%
import pandas as pd
import numpy as np
import logging
import importlib

from pathlib import Path

from bodaqs_analysis import run_macro
from bodaqs_analysis import normalize_and_scale
from bodaqs_analysis import estimate_va
from bodaqs_analysis import load_event_schema
from bodaqs_analysis import detect_events_from_schema
from bodaqs_analysis import extract_metrics_df


import bodaqs_analysis.widgets.event_browser as eb
importlib.reload(eb)
from bodaqs_analysis.widgets.metric_histogram_widget import make_metric_histogram_widget
from bodaqs_analysis.widgets.event_browser import make_event_browser_widget_for_loader


from bodaqs_analysis.artifacts import (
    ArtifactStore,
    make_run_id,
    save_session_artifacts,
    write_run_manifest,
    write_session_manifest,
    write_events_partitioned_by_schema_id,
    write_metrics_partitioned_by_schema_id,
    copy_raw_csv_to_source,
    ensure_run_is_new,
    ensure_session_is_new
)

logging.basicConfig(
    level=logging.INFO,
    format="%(levelname)s:%(name)s:%(message)s"
)

# logging.getLogger("bodaqs_analysis").setLevel(logging.DEBUG)
logging.getLogger("bodaqs_analysis.detect").setLevel(logging.INFO)

logger = logging.getLogger(__name__)

# %%
# ---- Inputs ----
CSV_PATH = r"C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25*.CSV"   # change to your log
SCHEMA_PATH = r"event schema\event_schema.yaml"
INGESTION_MODE = "tolerant"
ZEROING_ENABLED = "false"

# Columns and full-ranges (mm) for normalization (edit as needed)
NORMALIZE_RANGES = {
    "front_shock_dom_suspension [mm]": 170.0,
    "rear_shock_dom_suspension [mm]": 165.0,
}

SAMPLE_RATE_HZ = 200   # if known; used for VA estimation when time col is absent

# %%
# ---- Batch orchestration + artifact production ----
pattern = Path(CSV_PATH)
CSV_FILES = sorted(pattern.parent.glob(pattern.name))

if not CSV_FILES:
    raise FileNotFoundError(f"No CSV files matched: {CSV_PATH}")

logger.info(f"Found {len(CSV_FILES)} files:")
for p in CSV_FILES:
    logger.info("  %s", p.name)

# ---- Artifact init (one run_id per batch) ----
store = ArtifactStore(Path("artifacts"))
run_id = make_run_id(tz_label="AWST") 
ensure_run_is_new(store, run_id=run_id, force=False)
logger.info("Artifact run_id = %s", run_id)

events_all = []
metrics_all = []
sessions_by_id = {}
schema = None
session_ids_in_run = []

for p in CSV_FILES:
    logger.info("Processing %s ...", p.name)

    results = run_macro(
        str(p),
        SCHEMA_PATH,
        zeroing_enabled=ZEROING_ENABLED,
        normalize_ranges=NORMALIZE_RANGES,
        sample_rate_hz=SAMPLE_RATE_HZ,
        strict=(INGESTION_MODE == "strict"),
    )

    session = results["session"]
    sid = str(session["session_id"])
    ensure_session_is_new(store, run_id=run_id, session_id=sid, force=False)
    sessions_by_id[sid] = session
    session_ids_in_run.append(sid)

    # Copy raw CSV into artifacts
    source_sha256 = copy_raw_csv_to_source(store=store, run_id=run_id, session_id=sid, csv_path=p)

    # Save canonical session artifacts
    save_session_artifacts(
        store,
        run_id=run_id,
        session_id=sid,
        session_df=session["df"],
        session_meta=session["meta"],
    )

    # Write per-session manifest (minimal but useful)
    write_session_manifest(
        store,
        run_id=run_id,
        session_id=sid,
        contracts={"session": "v0.x", "events": "v0.x", "metrics": "v0.x"},
        source={
            "path": "source/input.csv",
            "sha256": source_sha256,
        },
        summary={"n_rows": int(len(session["df"]))},
    )

    # Freeze schema once per run (optional)
    if schema is None:
        schema = results.get("schema", None)

    # Events / Metrics tables (per schema_id)
    ev = results.get("events")
    mt = results.get("metrics")

    if isinstance(ev, pd.DataFrame) and not ev.empty and (ev["session_id"] != sid).any():
        raise ValueError(f"events_df session_id mismatch for sid={sid}")

    if isinstance(mt, pd.DataFrame) and not mt.empty and (mt["session_id"] != sid).any():
        raise ValueError(f"metrics_df session_id mismatch for sid={sid}")

    if isinstance(ev, pd.DataFrame) and not ev.empty:
        events_all.append(ev)
        write_events_partitioned_by_schema_id(
            store=store,
            run_id=run_id,
            session_id=sid,
            events_df=ev,
            schema_path=SCHEMA_PATH,
        )
    
    if isinstance(mt, pd.DataFrame) and not mt.empty:
        metrics_all.append(mt)
        write_metrics_partitioned_by_schema_id(
            store=store,
            run_id=run_id,
            session_id=sid,
            metrics_df=mt,
        )
    

# Batch-level combined dfs (your existing behavior)
events_df  = pd.concat(events_all, ignore_index=True) if events_all else pd.DataFrame()
metrics_df = pd.concat(metrics_all, ignore_index=True) if metrics_all else pd.DataFrame()

logging.debug("events_df: %s", events_df.shape)
logging.debug("metrics_df: %s", metrics_df.shape)

# Write run manifest (once per batch)
write_run_manifest(
    store,
    run_id=run_id,
    session_ids=session_ids_in_run,
    timezone_label="AWST",
    pipeline_config={
        "schema_path": str(SCHEMA_PATH),
        "zeroing_enabled": bool(ZEROING_ENABLED),
        "normalize_ranges": bool(NORMALIZE_RANGES),
        "sample_rate_hz": float(SAMPLE_RATE_HZ),
        "ingestion_mode": str(INGESTION_MODE),
        "n_files": int(len(CSV_FILES)),
    },
)

logger.info("Wrote artifacts for run_id=%s with %d sessions", run_id, len(session_ids_in_run))
# Out:
# INFO:__main__:Found 13 files:
# INFO:__main__:  2026-01-25_09-45-58.CSV
# INFO:__main__:  2026-01-25_10-09-00.CSV
# INFO:__main__:  2026-01-25_10-27-52.CSV
# INFO:__main__:  2026-01-25_10-49-10.CSV
# INFO:__main__:  2026-01-25_11-11-29.CSV
# INFO:__main__:  2026-01-25_11-35-12.CSV
# INFO:__main__:  2026-01-25_12-35-01.CSV
# INFO:__main__:  2026-01-25_12-54-47.CSV
# INFO:__main__:  2026-01-25_13-21-24.CSV
# INFO:__main__:  2026-01-25_13-42-38.CSV
# INFO:__main__:  2026-01-25_14-04-23.CSV
# INFO:__main__:  2026-01-25_14-13-31.CSV
# INFO:__main__:  2026-01-25_14-13-44.CSV
# INFO:__main__:Artifact run_id = run_2026-01-26T18-03-34_AWST
# INFO:__main__:Processing 2026-01-25_09-45-58.CSV ...
# INFO:bodaqs_analysis.pipeline:Session load complete: C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25_09-45-58.CSV
# INFO:bodaqs_analysis.pipeline:Session pre-process complete
# INFO:bodaqs_analysis.pipeline:Schema load complete
# INFO:bodaqs_analysis.detect:Built EVENTS_DF with 28 rows from 2 schema event(s) → 4 sensor-expanded event(s)
# INFO:bodaqs_analysis.pipeline:Event detection complete
# INFO:bodaqs_analysis.pipeline:events rows: 28
# INFO:bodaqs_analysis.pipeline:Schema events with zero detections this run: ['deep_compression']
# INFO:bodaqs_analysis.pipeline:Running segment extraction for detected schema events: ['rebounds']
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=rebounds): 28/28
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:Metrics validation complete
# INFO:__main__:Processing 2026-01-25_10-09-00.CSV ...
# INFO:bodaqs_analysis.pipeline:Session load complete: C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25_10-09-00.CSV
# INFO:bodaqs_analysis.pipeline:Session pre-process complete
# INFO:bodaqs_analysis.pipeline:Schema load complete
# INFO:bodaqs_analysis.detect:Built EVENTS_DF with 77 rows from 2 schema event(s) → 4 sensor-expanded event(s)
# INFO:bodaqs_analysis.pipeline:Event detection complete
# INFO:bodaqs_analysis.pipeline:events rows: 77
# INFO:bodaqs_analysis.pipeline:Running segment extraction for detected schema events: ['deep_compression', 'rebounds']
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=deep_compression): 9/9
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=rebounds): 68/68
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:Metrics validation complete
# INFO:__main__:Processing 2026-01-25_10-27-52.CSV ...
# INFO:bodaqs_analysis.pipeline:Session load complete: C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25_10-27-52.CSV
# INFO:bodaqs_analysis.pipeline:Session pre-process complete
# INFO:bodaqs_analysis.pipeline:Schema load complete
# INFO:bodaqs_analysis.detect:Built EVENTS_DF with 42 rows from 2 schema event(s) → 4 sensor-expanded event(s)
# INFO:bodaqs_analysis.pipeline:Event detection complete
# INFO:bodaqs_analysis.pipeline:events rows: 42
# INFO:bodaqs_analysis.pipeline:Schema events with zero detections this run: ['deep_compression']
# INFO:bodaqs_analysis.pipeline:Running segment extraction for detected schema events: ['rebounds']
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=rebounds): 42/42
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:Metrics validation complete
# INFO:__main__:Processing 2026-01-25_10-49-10.CSV ...
# INFO:bodaqs_analysis.pipeline:Session load complete: C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25_10-49-10.CSV
# INFO:bodaqs_analysis.pipeline:Session pre-process complete
# INFO:bodaqs_analysis.pipeline:Schema load complete
# INFO:bodaqs_analysis.detect:Built EVENTS_DF with 46 rows from 2 schema event(s) → 4 sensor-expanded event(s)
# INFO:bodaqs_analysis.pipeline:Event detection complete
# INFO:bodaqs_analysis.pipeline:events rows: 46
# INFO:bodaqs_analysis.pipeline:Running segment extraction for detected schema events: ['deep_compression', 'rebounds']
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=deep_compression): 4/4
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=rebounds): 42/42
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:Metrics validation complete
# INFO:__main__:Processing 2026-01-25_11-11-29.CSV ...
# INFO:bodaqs_analysis.pipeline:Session load complete: C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25_11-11-29.CSV
# INFO:bodaqs_analysis.pipeline:Session pre-process complete
# INFO:bodaqs_analysis.pipeline:Schema load complete
# INFO:bodaqs_analysis.detect:Built EVENTS_DF with 100 rows from 2 schema event(s) → 4 sensor-expanded event(s)
# INFO:bodaqs_analysis.pipeline:Event detection complete
# INFO:bodaqs_analysis.pipeline:events rows: 100
# INFO:bodaqs_analysis.pipeline:Running segment extraction for detected schema events: ['deep_compression', 'rebounds']
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=deep_compression): 1/1
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=rebounds): 99/99
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:Metrics validation complete
# INFO:__main__:Processing 2026-01-25_11-35-12.CSV ...
# INFO:bodaqs_analysis.pipeline:Session load complete: C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25_11-35-12.CSV
# INFO:bodaqs_analysis.pipeline:Session pre-process complete
# INFO:bodaqs_analysis.pipeline:Schema load complete
# INFO:bodaqs_analysis.detect:Built EVENTS_DF with 83 rows from 2 schema event(s) → 4 sensor-expanded event(s)
# INFO:bodaqs_analysis.pipeline:Event detection complete
# INFO:bodaqs_analysis.pipeline:events rows: 83
# INFO:bodaqs_analysis.pipeline:Running segment extraction for detected schema events: ['deep_compression', 'rebounds']
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=deep_compression): 7/7
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=rebounds): 76/76
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:Metrics validation complete
# INFO:__main__:Processing 2026-01-25_12-35-01.CSV ...
# INFO:bodaqs_analysis.pipeline:Session load complete: C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25_12-35-01.CSV
# INFO:bodaqs_analysis.pipeline:Session pre-process complete
# INFO:bodaqs_analysis.pipeline:Schema load complete
# INFO:bodaqs_analysis.detect:Built EVENTS_DF with 124 rows from 2 schema event(s) → 4 sensor-expanded event(s)
# INFO:bodaqs_analysis.pipeline:Event detection complete
# INFO:bodaqs_analysis.pipeline:events rows: 124
# INFO:bodaqs_analysis.pipeline:Running segment extraction for detected schema events: ['deep_compression', 'rebounds']
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=deep_compression): 5/5
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=rebounds): 119/119
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:Metrics validation complete
# INFO:__main__:Processing 2026-01-25_12-54-47.CSV ...
# INFO:bodaqs_analysis.pipeline:Session load complete: C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25_12-54-47.CSV
# INFO:bodaqs_analysis.pipeline:Session pre-process complete
# INFO:bodaqs_analysis.pipeline:Schema load complete
# INFO:bodaqs_analysis.detect:Built EVENTS_DF with 71 rows from 2 schema event(s) → 4 sensor-expanded event(s)
# INFO:bodaqs_analysis.pipeline:Event detection complete
# INFO:bodaqs_analysis.pipeline:events rows: 71
# INFO:bodaqs_analysis.pipeline:Running segment extraction for detected schema events: ['deep_compression', 'rebounds']
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=deep_compression): 1/1
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=rebounds): 70/70
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:Metrics validation complete
# INFO:__main__:Processing 2026-01-25_13-21-24.CSV ...
# INFO:bodaqs_analysis.pipeline:Session load complete: C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25_13-21-24.CSV
# INFO:bodaqs_analysis.pipeline:Session pre-process complete
# INFO:bodaqs_analysis.pipeline:Schema load complete
# INFO:bodaqs_analysis.detect:Built EVENTS_DF with 107 rows from 2 schema event(s) → 4 sensor-expanded event(s)
# INFO:bodaqs_analysis.pipeline:Event detection complete
# INFO:bodaqs_analysis.pipeline:events rows: 107
# INFO:bodaqs_analysis.pipeline:Running segment extraction for detected schema events: ['deep_compression', 'rebounds']
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=deep_compression): 2/2
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=rebounds): 105/105
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:Metrics validation complete
# INFO:__main__:Processing 2026-01-25_13-42-38.CSV ...
# INFO:bodaqs_analysis.pipeline:Session load complete: C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25_13-42-38.CSV
# INFO:bodaqs_analysis.pipeline:Session pre-process complete
# INFO:bodaqs_analysis.pipeline:Schema load complete
# INFO:bodaqs_analysis.detect:Built EVENTS_DF with 94 rows from 2 schema event(s) → 4 sensor-expanded event(s)
# INFO:bodaqs_analysis.pipeline:Event detection complete
# INFO:bodaqs_analysis.pipeline:events rows: 94
# INFO:bodaqs_analysis.pipeline:Running segment extraction for detected schema events: ['deep_compression', 'rebounds']
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=deep_compression): 1/1
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=rebounds): 93/93
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:Metrics validation complete
# INFO:__main__:Processing 2026-01-25_14-04-23.CSV ...
# INFO:bodaqs_analysis.pipeline:Session load complete: C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25_14-04-23.CSV
# INFO:bodaqs_analysis.pipeline:Session pre-process complete
# INFO:bodaqs_analysis.pipeline:Schema load complete
# INFO:bodaqs_analysis.detect:Built EVENTS_DF with 72 rows from 2 schema event(s) → 4 sensor-expanded event(s)
# INFO:bodaqs_analysis.pipeline:Event detection complete
# INFO:bodaqs_analysis.pipeline:events rows: 72
# INFO:bodaqs_analysis.pipeline:Running segment extraction for detected schema events: ['deep_compression', 'rebounds']
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=deep_compression): 4/4
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=deep_compression)
# INFO:bodaqs_analysis.pipeline:Segment extraction complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:segments valid (schema_id=rebounds): 68/68
# INFO:bodaqs_analysis.pipeline:Metrics calculation complete (schema_id=rebounds)
# INFO:bodaqs_analysis.pipeline:Metrics validation complete
# INFO:__main__:Processing 2026-01-25_14-13-31.CSV ...
# INFO:bodaqs_analysis.pipeline:Session load complete: C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25_14-13-31.CSV
# INFO:bodaqs_analysis.pipeline:Session pre-process complete
# INFO:bodaqs_analysis.pipeline:Schema load complete
# INFO:bodaqs_analysis.detect:Built EVENTS_DF with 0 rows from 2 schema event(s) → 4 sensor-expanded event(s)
# INFO:bodaqs_analysis.pipeline:Event detection complete
# INFO:bodaqs_analysis.pipeline:events rows: 0
# INFO:bodaqs_analysis.pipeline:Schema events with zero detections this run: ['deep_compression', 'rebounds']
# INFO:bodaqs_analysis.pipeline:Running segment extraction for detected schema events: []
# INFO:bodaqs_analysis.pipeline:Metrics validation complete
# INFO:__main__:Processing 2026-01-25_14-13-44.CSV ...
# INFO:bodaqs_analysis.pipeline:Session load complete: C:\Users\Ben Connor\OneDrive\Documents\logs\2026-01-25_14-13-44.CSV
# INFO:bodaqs_analysis.pipeline:Session pre-process complete
# INFO:bodaqs_analysis.pipeline:Schema load complete
# INFO:bodaqs_analysis.detect:Built EVENTS_DF with 0 rows from 2 schema event(s) → 4 sensor-expanded event(s)
# INFO:bodaqs_analysis.pipeline:Event detection complete
# INFO:bodaqs_analysis.pipeline:events rows: 0
# INFO:bodaqs_analysis.pipeline:Schema events with zero detections this run: ['deep_compression', 'rebounds']
# INFO:bodaqs_analysis.pipeline:Running segment extraction for detected schema events: []
# INFO:bodaqs_analysis.pipeline:Metrics validation complete
# INFO:__main__:Wrote artifacts for run_id=run_2026-01-26T18-03-34_AWST with 13 sessions

# %%
make_metric_histogram_widget(
    events_df,
    metrics_df,
    event_type_col="event_name",
    signal_col="signal_col",
    default_bins=10,
)
# Out:
# INFO:bodaqs_analysis.widgets.metric_histogram_widget:metric_histogram: joined viz_df shape: (844, 9)
# VBox(children=(VBox(children=(HBox(children=(Dropdown(description='Event:', options=('all rebound events >0.4'…
# {'viz_df':               session_id                 event_id               event_name  \
#  0    2026-01-25_09-45-58    rebounds:rear_shock:0  all rebound events >0.4
#  1    2026-01-25_09-45-58   rebounds:front_shock:0  all rebound events >0.4
#  2    2026-01-25_09-45-58    rebounds:rear_shock:1  all rebound events >0.4
#  3    2026-01-25_09-45-58   rebounds:front_shock:1  all rebound events >0.4
#  4    2026-01-25_09-45-58    rebounds:rear_shock:2  all rebound events >0.4
#  ..                   ...                      ...                      ...
#  839  2026-01-25_14-04-23  rebounds:front_shock:36  all rebound events >0.4
#  840  2026-01-25_14-04-23  rebounds:front_shock:37  all rebound events >0.4
#  841  2026-01-25_14-04-23  rebounds:front_shock:38  all rebound events >0.4
#  842  2026-01-25_14-04-23   rebounds:rear_shock:27  all rebound events >0.4
#  843  2026-01-25_14-04-23  rebounds:front_shock:39  all rebound events >0.4
#
#                                  signal_col  m_interval_vel_mean  \
#  0     rear_shock_vel_dom_suspension [mm/s]           -49.533255
#  1    front_shock_vel_dom_suspension [mm/s]           -93.223815
#  2     rear_shock_vel_dom_suspension [mm/s]          -106.394027
#  3    front_shock_vel_dom_suspension [mm/s]           -19.567428
#  4     rear_shock_vel_dom_suspension [mm/s]          -143.453478
#  ..                                     ...                  ...
#  839  front_shock_vel_dom_suspension [mm/s]           -41.947106
#  840  front_shock_vel_dom_suspension [mm/s]           -55.101630
#  841  front_shock_vel_dom_suspension [mm/s]          -218.338172
#  842   rear_shock_vel_dom_suspension [mm/s]          -209.562889
#  843  front_shock_vel_dom_suspension [mm/s]          -266.768631
#
#       m_interval_vel_max  m_interval_vel_min  m_interval_disp_delta  \
#  0             -1.716055          -98.067744             -22.786453
#  1            -21.355489         -164.580759             -68.621156
#  2            -27.779547         -160.783658             -67.760944
#  3             -9.919577          -30.605631              -2.454407
#  4              1.267746         -243.222827             -69.430191
#  ..                  ...                 ...                    ...
#  839           -3.747038          -71.647478             -31.958439
#  840           -7.542519          -79.648846              -7.925694
#  841           70.245789         -330.814487             -89.943825
#  842           48.910238         -460.547778             -56.876762
#  843          -48.675588         -373.827206             -42.543076
#
#       m_peak_disp_max
#  0          59.697582
#  1          62.485138
#  2          60.039494
#  3          50.928970
#  4          60.609348
#  ..               ...
#  839        63.456673
#  840        78.438789
#  841       142.509064
#  842       124.479523
#  843       114.896980
#
#  [844 rows x 9 columns],
#  'out': Output()}

# %%
from bodaqs_analysis.widgets.event_browser import make_event_browser_widget_for_loader

def session_loader(session_id: str) -> dict:
    return sessions_by_id[str(session_id)]

wb = make_event_browser_widget_for_loader(
    schema,
    events_df,
    session_loader=session_loader,
)
# Out:
# VBox(children=(HBox(children=(SelectMultiple(description='Sessions:', index=(0,), layout=Layout(height='120px'…

# %%
from bodaqs_analysis.widgets.metric_scatter_widget import make_metric_scatter_widget

handles = make_metric_scatter_widget(
    events_df=events_df,
    metrics_df=metrics_df,
    event_type_col="event_name",   # or "event_type"/"schema_id" depending on your table
    signal_col="signal_col",
)

viz_df = handles["viz_df"]  # handy for debugging
# Out:
# INFO:bodaqs_analysis.widgets.metric_scatter_widget:metric_scatter: joined viz_df shape: (844, 10)
# VBox(children=(VBox(children=(HBox(children=(Dropdown(description='Event:', options=('all rebound events >0.4'…

# %%
from bodaqs_analysis.widgets.signal_histogram_widget import (
    make_signal_histogram_widget_for_loader
)

def session_loader(session_id: str) -> dict:
    return sessions_by_id[str(session_id)]

wh = make_signal_histogram_widget_for_loader(
    events_df,
    session_loader=session_loader,
    default_bins=50,
)
# Out:
# VBox(children=(VBox(children=(HBox(children=(BoundedIntText(value=50, description='Bins:', max=500, min=1), Ch…
